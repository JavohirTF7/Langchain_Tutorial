# %% [markdown]
# <a href="https://colab.research.google.com/github/JavohirTF7/Langchain_Tutorial/blob/main/openai_api_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
from getpass import getpass
import os

# API kalitni ko‘rinmaydigan tarzda kiritamiz
os.environ["OPENAI_API_KEY"] = getpass("OpenAI API kalitingizni kiriting: ")

# %%
from openai import OpenAI
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# %%
def ask_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

# %%
javob = ask_gpt("Salom?")
print(javob)
